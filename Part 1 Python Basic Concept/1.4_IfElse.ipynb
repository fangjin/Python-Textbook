# %% [markdown]
# 1.2 If Else

# %%
# Questions:

## Q1.
a = int(input('Please input a number.'))
if a > 1:
    print('a>1')
if a < 1:
    print('a<1')
if a == 1:
    print('a==1')

## Q2.
a = 1
if a > 1:
    print('a>1')
elif a < 2:
    print('a<1')

## Q3.
a = 1
if a > 1:
    print('a>1')
elif a < 1:
    print('a<1')
# Out:
# Please input a number.2
# a>1
# a<1

# %%
## P1
# Variables to keep track of the pet's status
pet_name = "Fluffy"
hunger = 10  # Scale of 1-10, where 10 is very hungry
energy = 10  # Scale of 1-10, where 10 is full of energy
happiness = 10  # Scale of 1-10, where 10 is very happy

evolution = 1

# pet status
if evolution > 0 and hunger >= 10 and energy >= 10 and happiness >= 10:
  print(f"\n{pet_name} has successfully evolved.")
  print(f"1.You need to upgrade your code yourself to complete the subsequent evolution design or even battles.")
  print(f"2.You can design or upload a character for your companions.")
  print(f"For more information, please contact your teacher.")
else:
  print("Your Monster has not evolved.")

# feed your pet
if hunger < 9:
    hunger += 2  # Feeding decreases hunger
    happiness += 1
    print(f"\nYou fed {pet_name}. Yum!")
else:
    print(f"\n{pet_name} is not very hungry right now.")

# play with your pet
if energy > 2:
    if happiness < 9:
      happiness += 2  # Playing increases happiness
    else:
      happiness = 10
    energy -= 2  # Playing decreases energy
    hunger -= 1
    print(f"\nYou played with {pet_name}. Fun!")
else:
    print(f"\n{pet_name} is too tired to play.")

# let your pet sleep
if energy < 8:
    energy += 3  # Sleeping increases energy
    hunger -= 1
    happiness -= 1
    print(f"\n{pet_name} is sleeping. Zzz...")
else:
    print(f"\n{pet_name} is not very tired, {pet_name} do not want to sleep.")
# Out:
# Fluffy has successfully evolved.
# 1.You need to upgrade your code yourself to complete the subsequent evolution design or even battles.
# 2.You can design or upload a character for your companions.
# For more information, please contact your teacher.
#
# Fluffy is not very hungry right now.
#
# You played with Fluffy. Fun!
#
# Fluffy is not very tired, Fluffy do not want to sleep.

# %%
## P2
board = [[" " for _ in range(3)] for _ in range(3)]
# The result of board is the same as: Board_List = [[' ',' ',' '],[' ',' ',' '],[' ',' ',' ']]
print(board)

row = 1
col = 2

if board[row][col] != " ":
  print("That position is already taken!")
else:
  print('Action has been taken.')
# Out:
# [[' ', ' ', ' '], [' ', ' ', ' '], [' ', ' ', ' ']]

# %%
## P3.
# Simulation of an ATM machine
account_number = "123456"
pin = "1234"
balance = 1000

user_account = input("Enter your account number: ")
user_pin = input("Enter your PIN: ")
amount = float(input("Enter amount to deposit: "))

# Login.
if user_account == account_number and user_pin == pin:
    print(True)
else:
    print(False)

# withdraw
if amount <= balance:
    balance -= amount
    print(f"${amount} withdrawn successfully.")
else:
    print("Insufficient balance.")

print("\n1. Deposit")
print("2. Withdraw")
print("3. Check Balance")
print("4. Exit")
choice = input("Choose an option (1-4): ")

# select a choice
if choice == "1":
  print('deposit')
elif choice == "2":
  print('withdraw')
elif choice == "3":
  print('check_balance')
elif choice == "4":
  print('Thank you for using the Mini ATM Simulator. Goodbye!')
else:
  print("Invalid choice. Please enter a number between 1 and 4.")
# Out:
# Please enter your account.1
# Please enter your pin number.22
# Please enter the amount you want to withdraw.102
# False
# True
# True
# False
# True
# True
# False
# True
# False
# [False False False]
# [ True  True  True]
# [False False  True]

# %%
## P4.
size=5
player_x, player_y = 0, 0  # Starting position of the player

move = input("Move (WASD): ").upper()
if move == "W" and player_x > 0:
    player_x -= 1
elif move == "S" and player_x < size - 1:
    player_x += 1
elif move == "A" and player_y > 0:
    player_y -= 1
elif move == "D" and player_y < size - 1:
    player_y += 1
else:
    print("Invalid move or boundary reached. Please try again.")
# Out:
# Move (WASD): S
