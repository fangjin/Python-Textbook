# %% [markdown]
# 1.2 Dictionary

# %%
# Questions:

## Q1.
list_C = {'A':[1]}
dic_A = {'a': 1, 'b': True, 'c': list_C, 'd':[1,2,True]}
print(dic_A.values())

## Q2.
list_C = {'A':[1]}
dic_A = {'a': 1, 'b': True}
dic_A['b'] = False
dic_A['c'] = False
print(dic_A)
# Out:
# dict_values([1, True, {'A': [1]}, [1, 2, True]])
# {'a': 1, 'b': False, 'c': False}

# %%
## P1
# Imagine that you've many pets (may be Pokémon?), and you plan to train them. Please first define and initial your pets. Hint(Let every variable be a list, and pets be a dictionary.)
pet_name = ['A','B','C']
hunger = [5,5,5]
energy = [6,7,4]
happiness = [2,7,10]

Pets = {'pet name':pet_name,'hunger':hunger,'energy':energy,'happiness':happiness}
print(Pets)

# How about let every pet be a dictionary?
A = {'pet name':'A','hunger':5,'energy':6,'happiness':2}
B = {'pet name':'B','hunger':5,'energy':7,'happiness':7}
C = {'pet name':'C','hunger':5,'energy':4,'happiness':10}

Pets = {'A':A,'B':B,'C':C}
print(Pets['A'])
print(Pets['B'])
print(Pets['C'])
# Out:
# {'pet name': ['A', 'B', 'C'], 'hunger': [5, 5, 5], 'energy': [6, 7, 4], 'happiness': [2, 7, 10]}
# {'pet name': 'A', 'hunger': 5, 'energy': 6, 'happiness': 2}
# {'pet name': 'B', 'hunger': 5, 'energy': 7, 'happiness': 7}
# {'pet name': 'C', 'hunger': 5, 'energy': 4, 'happiness': 10}

# %%
## P2.
# Simulation of an ATM machine
# Let us suppose there are several customers, we want to initialize their account and store them in a dictionary.
customer_A = {'indx': 1, 'account_number': 123, 'pin': 11, 'balance': 0}
customer_B = {'indx': 2, 'account_number': 233, 'pin': 22, 'balance': 100}
customer_C = {'indx': 3, 'account_number': 456, 'pin': 33, 'balance': 1000}

customers = [customer_A, customer_B, customer_C]
# Out:
# Please enter your account.1
# Please enter your pin number.22
# Please enter the amount you want to withdraw.102
# False
# True
# True
# False
# True
# True
# False
# True
# False
# [False False False]
# [ True  True  True]
# [False False  True]
