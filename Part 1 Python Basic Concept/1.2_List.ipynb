# %% [markdown]
# 1.2 List

# %%
# Questions:
list_A = ['a', 'b', 'c']
list_B = [1, 2, 3]
list_C = [True, False, True]
list_A

## Q1.
x = [1, 2, 3]
y = x
x[1] = input('Enter a word here.')
print(x,y)
x = [1, 2, 3]
y = x.copy()
x[1] = input('Enter a word here.')
print(x,y)

## Q3.
print(list_A[1:5])
print(list_B[1:1])
print(list_C[1:-1])
# Out:
# Enter a word here.r
# [1, 'r', 3] [1, 'r', 3]
# Enter a word here.r
# [1, 'r', 3] [1, 2, 3]
# ['b', 'c']
# []
# [False]

# %%
## P1
# Imagine that you've raised many pets (may be Pokémon?). Please first define and initial your pets. Hint(Let every variable be a list)
pet_name = ['A','B','C']
hunger = [5,5,5]
energy = [6,7,4]
happiness = [2,7,10]

Monsters = [monster_name,hunger,energy,happiness]

# %%
## P2
# Use a list to store an initialized chessboard, and then record the pieces of both sides on the chessboard in the list. Finally, print it out!
'''
+---+---+---+
| O |   |   |
+---+---+---+
|   | X |   |
+---+---+---+
|   |   | O |
+---+---+---+
'''

separator = " +---+---+---+"

Board_List = [[' ',' ',' '],
              [' ',' ',' '],
              [' ',' ',' ']]

Board_List[0][0] = 'O'
Board_List[1][1] = 'X'
Board_List[2][2] = 'O'

print(separator)
print(' |',Board_List[0][0],'|',Board_List[0][1],'|',Board_List[0][2],'|')
print(separator)
print(' |',Board_List[1][0],'|',Board_List[1][1],'|',Board_List[1][2],'|')
print(separator)
print(' |',Board_List[2][0],'|',Board_List[2][1],'|',Board_List[2][2],'|')
print(separator)
# Out:
#  +---+---+---+
#  | O |   |   |
#  +---+---+---+
#  |   | X |   |
#  +---+---+---+
#  |   |   | O |

# %%
## P3.
# Simulation of an ATM machine
# Let us suppose there are several customers, we want to initialize their account and let one of them input and check his account.
#1. Initialize the account.
account_number = [123, 233, 456]
pin = [11, 22, 33]
balance = [0, 100, 1000]


# 2. Get some variables from input
user_account = input('Please enter your account.')
user_pin = input('Please enter your pin number.')
amount = float(input('Please enter the amount you want to withdraw.'))


# 3. Print out if the account_number is equal to user_account, the opposite to pin, and if amount is larger than your balance
print( user_account == account_number[0])
print( user_pin != pin[0])
print( amount > balance[0])

print( user_account == account_number[1])
print( user_pin != pin[1])
print( amount > balance[1])

print( user_account == account_number[2])
print( user_pin != pin[2])
print( amount > balance[2])

# brief introduction to numpy
import numpy as np
N_account = np.array(account_number)
N_pin = np.array(pin)
N_balance = np.array(balance)

print( N_account == user_account)
print( N_pin != user_pin)
print( N_balance > amount)
# Out:
# Please enter your account.1
# Please enter your pin number.22
# Please enter the amount you want to withdraw.102
# False
# True
# True
# False
# True
# True
# False
# True
# False
# [False False False]
# [ True  True  True]
# [False False  True]

# %%
## P4.
# Please save a 3x3 dot map like this in to a list, and then print it out:
'''
P . .
. T .
. . .
'''

dot_map =  [['P','.','.'],
            ['.','T','.'],
            ['.','.','.']]

print('\t',dot_map[0][0],dot_map[0][1],dot_map[0][2],'\n\t',dot_map[1][0],dot_map[1][1],dot_map[1][2],'\n\t',dot_map[2][0],dot_map[2][1],dot_map[2][2])
# Out:
# 	 P . .
# 	 . T .
# 	 . . .
#
#  True
#
#  False
