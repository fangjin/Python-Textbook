# %% [markdown]
# 1.1 Variables

# %%
# Questions:
# 1.
x = y = z = 3
print(x,y,z)

# 2.
print(x==y==z)

# 3.
x,y = 3,4
print(x,y,z)
print(x==z==y)
# Out:
# 3 3 3
# True
# 3 4 3
# False

# %%
## Q4.
# Imagine that you've captured a Pocket Monster (may be Pokémon?), and you plan to train it. Please first define and initial your Monster.
monster_name = 'Pikhaha'
hunger = 5     # Scale of 1-10, where 10 is very hungry
energy = 7     # Scale of 1-10, where 10 is full of energy
happiness = 8  # Scale of 1-10, where 10 is very happy

# %%
## Q5
#Please print a 3x3 dot map like this:
'''
P . .
. T .
. . .
'''

print('P . .')
print('. T .')
print('. . .')

# print('P . .\n. T .\n. . .')

# %%
## P1.
#1. print a game board
separator = " +---+---+---+"
print(separator)
print(' |   |   |   |')
print(separator)
print(' |   |   |   |')
print(separator)
print(' |   |   |   |')
print(separator)

#2. use input() to let one of the player to select row and column
'''Try to understand the Hint:
   #1.
   a = 'w'
   print(f'What does this {a} mean?')
   #2. continue with Hint1
   b = input(f'Player {a}, please enter the row of the game board.')
   print(b)'''

select_A_rpw = input('Player A, please enter the row of the game board.')
select_A_column = input('Player A, please enter the column of the game board.')
select_B_row = input('Player B, please enter the row of the game board.')
select_B_column = input('Player B, please enter the column of the game board.')

#3. other circumstances to print
print("That position is already taken!")
# print(f"Player {current_player} wins!")
print("It's a tie!")
# Out:
#  +---+---+---+
#  |   |   |   |
#  +---+---+---+
#  |   |   |   |
#  +---+---+---+
#  |   |   |   |
#  +---+---+---+
# Player A, please enter the row of the game board.1
# Player A, please enter the column of the game board.2
# Player B, please enter the row of the game board.3
# Player B, please enter the column of the game board.4
# That position is already taken!
# It's a tie!

# %%
## P2.
#Simulation of an ATM machine
#Have you wondered how the vending machine, or the ATM machine works? they allows you to input password and draw money, this is actually, very easy to design.
#1. Initialize the account.
account_number = 690157
pin = 7263
balance = 0.19  # Starting balance


# 2. Get some variables from input
user_account = input('Please enter your account.')
user_pin = input('Please enter your pin number.')
amount = float(input('Please enter the amount you want to withdraw.'))


# 3. Print out if the account_number is equal to user_account, the opposite to pin, and if amount is larger than your balance
print(account_number == user_account)
print(pin != user_pin)
print(amount > balance)
# Out:
# Please enter your account.1
# Please enter your pin number.3
# Please enter the amount you want to withdraw.2
# False
# True
# True

# %%
## P3.
# What will happen if we run the program below? Please make it correct. (Hint: Debug exercise)

# 2000born_number = 1999
# born number 1999 = 2000
# print(2000born_number <> born number 1999)
# print(2000born_number = born number 1999)

S2000born_number = 1999
born_number_1999 = 2000
print('\n',S2000born_number != born_number_1999)
print('\n',S2000born_number == born_number_1999)
# Out:
# P . .
# . T .
# . . .
#
#  True
#
#  False
