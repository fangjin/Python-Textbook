# %%
## P1
with open('file.txt', 'w') as file:
    file.write("I want to tell you a secret that ……\n")

# %%
## P2
with open('file.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# I want to tell you a secret that ……

# %%
## P3
with open('file.txt', 'a') as file:
    file.write("\nGot it.")

# %%
## P4
with open('file.txt', 'r') as file:
    content = file.read()
    print(content)

import os
os.remove('file.txt')
# Out:
# I want to tell you a secret that ……
#
# Got it.
